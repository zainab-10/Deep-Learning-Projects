# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from keras.models import load_model
import tensorflow as tf
face_mask_model=tf.keras.models.load_model("/content/drive/My Drive/Colab Notebooks/my projects/face_mask_detection/FaceMaskModel.h5")

# %%
face_mask_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_5 (Conv2D)           (None, 46, 46, 32)        320
#
#  conv2d_6 (Conv2D)           (None, 44, 44, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 128)       73856
#
#  dropout_4 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_8 (Conv2D)           (None, 10, 10, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  dropout_5 (Dropout)         (None, 3, 3, 256)         0
#
#  conv2d_9 (Conv2D)           (None, 1, 1, 256)         590080
#
#  dropout_6 (Dropout)         (None, 1, 1, 256)         0
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 1024)              263168
#
#  dense_4 (Dense)             (None, 1024)              1049600
#
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread("/content/drive/My Drive/Colab Notebooks/my projects/face_mask_detection/1.png")
cv2_imshow(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
resized = cv2.resize(img, (48,48), interpolation = cv2.INTER_AREA)
cv2_imshow(resized)
print(resized.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F2644615F70>
# (48, 48, 3)

# %%
gray_image = cv2.cvtColor(resized, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
print(gray_image.shape)
# Out:
# <PIL.Image.Image image mode=L size=48x48 at 0x7F26517FBDC0>
# (48, 48)

# %%
import numpy as np
# from keras.preprocessing import image
from tensorflow.keras.preprocessing import image
test_image=image.img_to_array(gray_image)
test_image=np.expand_dims(test_image,axis=0)
result=new_model.predict(test_image)

if result[0][0]==1:
  prediction='with_mask'
  print(prediction)
else:
  prediction='without_mask'
  print(prediction)
# Out:
# 1/1 [==============================] - 0s 334ms/step
# with_mask

# %%
# Importing the PIL library
from PIL import Image
from PIL import ImageDraw
import matplotlib.pyplot as plt

#open the image
img = Image.open('/content/drive/My Drive/Colab Notebooks/my projects/face_mask_detection/1.png')
# Call draw Method to add 2D graphics in an image
I1 = ImageDraw.Draw(img)

from PIL import ImageFont
myFont = ImageFont.truetype('/usr/share/fonts/truetype/liberation/LiberationMono-Regular.ttf', 180)

# Add Text to an image
I1.text((28, 36),prediction, font=myFont, fill=(255, 0, 0))
# Display edited image
# img.show()
plt.imshow(img)

#save the image
img.save("/content/drive/My Drive/Colab Notebooks/my projects/face_mask_detection/with-mask.png")

# %%
import cv2
img1 = cv2.imread("/content/drive/My Drive/Colab Notebooks/my projects/face_mask_detection/download.jpg")
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F263DADB6D0>

# %%
resized1 = cv2.resize(img1, (48,48), interpolation = cv2.INTER_AREA)
cv2_imshow(resized1)
print(resized1.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F263DBDE790>
# (48, 48, 3)

# %%
gray_image1 = cv2.cvtColor(resized1, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image1)
print(gray_image1.shape)
# Out:
# <PIL.Image.Image image mode=L size=48x48 at 0x7F263DB62700>
# (48, 48)

# %%
import numpy as np
# from keras.preprocessing import image
from tensorflow.keras.preprocessing import image
test_image=image.img_to_array(gray_image1)
test_image=np.expand_dims(test_image,axis=0)
result=new_model.predict(test_image)

if result[0][0]==1:
  prediction='with_mask'
  print(prediction)
else:
  prediction='without_mask'
  print(prediction)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# without_mask

# %%
# Importing the PIL library
from PIL import Image
from PIL import ImageDraw
import matplotlib.pyplot as plt
# Open an Image
img1 = Image.open('/content/drive/My Drive/Colab Notebooks/my projects/face_mask_detection/download.jpg')

# Call draw Method to add 2D graphics in an image
I1 = ImageDraw.Draw(img1)

from PIL import ImageFont
myFont = ImageFont.truetype('/usr/share/fonts/truetype/liberation/LiberationMono-Regular.ttf', 25)

# Add Text to an image
I1.text((28, 36), "without mask", font=myFont, fill=(255, 0, 0))

# Display edited image
plt.imshow(img1)

# Save the edited image
img1.save("/content/drive/My Drive/Colab Notebooks/my projects/face_mask_detection/without_mask.jpg")
