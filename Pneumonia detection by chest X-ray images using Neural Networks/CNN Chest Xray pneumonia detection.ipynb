# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
import tensorflow as tf
import numpy as np
import cv2
import os
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers,models
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.utils import to_categorical, plot_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_path='/content/drive/My Drive/Colab Notebooks/ANN_CNN_chest_Xray_Pneumonia_detection/chest_xray/train'
test_path='/content/drive/My Drive/Colab Notebooks/ANN_CNN_chest_Xray_Pneumonia_detection/chest_xray/test'

# %%
pip install pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (7.1.2)

# %%
# import required module
from PIL import Image
  
# get image
filepath = "/content/drive/My Drive/Colab Notebooks/ANN_CNN_chest_Xray_Pneumonia_detection/chest_xray/test/NORMAL/IM-0001-0001.jpeg"
img = Image.open(filepath)

# %%
# get width and height
width = img.width
height = img.height

# %%
# display width and height
print("The height of the image is: ", height)
print("The width of the image is: ", width)
# Out:
# The height of the image is:  1317
# The width of the image is:  1857

# %%
import os

# %%
print(os.listdir(train_path))
# Out:
# ['PNEUMONIA', 'NORMAL']

# %%
print(os.listdir(test_path))
# Out:
# ['NORMAL', 'PNEUMONIA']

# %%
# Initialize image data generator with rescaling
train_data_gen = ImageDataGenerator(rescale=1./255)
test_data_gen = ImageDataGenerator(rescale=1./255)

# %%
# Preprocess all train images
train_generator = train_data_gen.flow_from_directory(
        '/content/drive/My Drive/Colab Notebooks/ANN_CNN_chest_Xray_Pneumonia_detection/chest_xray/train',
        target_size=(48, 48),
        batch_size=32,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 5216 images belonging to 2 classes.

# %%
# Preprocess all test images
test_generator = test_data_gen.flow_from_directory(
        '/content/drive/My Drive/Colab Notebooks/ANN_CNN_chest_Xray_Pneumonia_detection/chest_xray/test',
        target_size=(48, 48),
        batch_size=32,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 624 images belonging to 2 classes.

# %%
# create model structure
from keras.models import Sequential
pheumonia_detection_model = Sequential()

# %%
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten
pheumonia_detection_model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48, 48, 1)))
pheumonia_detection_model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
pheumonia_detection_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
pheumonia_detection_model.add(MaxPooling2D(pool_size=(3, 3)))
pheumonia_detection_model.add(Dropout(0.25))

# %%
pheumonia_detection_model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
pheumonia_detection_model.add(MaxPooling2D(pool_size=(3, 3)))
pheumonia_detection_model.add(Dropout(0.25))
pheumonia_detection_model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
pheumonia_detection_model.add(MaxPooling2D(pool_size=(2, 2)))
pheumonia_detection_model.add(Dropout(0.25))

# %%
pheumonia_detection_model.add(Flatten())
pheumonia_detection_model.add(Dense(1024, activation='relu'))
pheumonia_detection_model.add(Dropout(0.5))
pheumonia_detection_model.add(Dense(2, activation='softmax'))

# %%
pheumonia_detection_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 44, 44, 64)        18496
#
#  conv2d_2 (Conv2D)           (None, 42, 42, 128)       73856
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 128)      0
#  )
#
#  dropout (Dropout)           (None, 14, 14, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 256)       295168
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 4, 4, 256)         0
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 256)         590080
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 1, 1, 256)         0
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 1024)              263168
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 2)                 2050
#
# =================================================================
# Total params: 1,243,138
# Trainable params: 1,243,138
# Non-trainable params: 0
# _________________________________________________________________

# %%
import cv2
cv2.ocl.setUseOpenCL(False)

# %%
from tensorflow.keras.optimizers import Adam

# %%
pheumonia_detection_model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=0.001), metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# Train the neural network/model
pheumonia_model_info = pheumonia_detection_model.fit(
        train_generator,
        steps_per_epoch=5216 // 64,
        epochs=20,
        validation_data=test_generator,
        validation_steps=624 // 64)
# Out:
# Epoch 1/20
# 81/81 [==============================] - 396s 5s/step - loss: 0.5770 - accuracy: 0.7296 - val_loss: 0.6252 - val_accuracy: 0.6007
# Epoch 2/20
# 81/81 [==============================] - 211s 3s/step - loss: 0.3562 - accuracy: 0.8380 - val_loss: 0.4366 - val_accuracy: 0.7778
# Epoch 3/20
# 81/81 [==============================] - 131s 2s/step - loss: 0.2347 - accuracy: 0.9097 - val_loss: 0.5550 - val_accuracy: 0.7500
# Epoch 4/20
# 81/81 [==============================] - 97s 1s/step - loss: 0.1645 - accuracy: 0.9348 - val_loss: 0.7496 - val_accuracy: 0.7535
# Epoch 5/20
# 81/81 [==============================] - 83s 1s/step - loss: 0.1496 - accuracy: 0.9390 - val_loss: 0.3700 - val_accuracy: 0.8438
# Epoch 6/20
# 81/81 [==============================] - 73s 902ms/step - loss: 0.1302 - accuracy: 0.9464 - val_loss: 0.5195 - val_accuracy: 0.7917
# Epoch 7/20
# 81/81 [==============================] - 74s 912ms/step - loss: 0.1121 - accuracy: 0.9541 - val_loss: 0.3954 - val_accuracy: 0.8333
# Epoch 8/20
# 81/81 [==============================] - 72s 880ms/step - loss: 0.0915 - accuracy: 0.9645 - val_loss: 0.3484 - val_accuracy: 0.8819
# Epoch 9/20
# 81/81 [==============================] - 72s 883ms/step - loss: 0.0960 - accuracy: 0.9649 - val_loss: 0.6139 - val_accuracy: 0.8160
# Epoch 10/20
# 81/81 [==============================] - 72s 882ms/step - loss: 0.0969 - accuracy: 0.9668 - val_loss: 0.4825 - val_accuracy: 0.8194
# Epoch 11/20
# 81/81 [==============================] - 71s 872ms/step - loss: 0.0846 - accuracy: 0.9703 - val_loss: 0.7194 - val_accuracy: 0.7986
# Epoch 12/20
# 81/81 [==============================] - 73s 903ms/step - loss: 0.0732 - accuracy: 0.9734 - val_loss: 0.4454 - val_accuracy: 0.8472
# Epoch 13/20
# 81/81 [==============================] - 72s 888ms/step - loss: 0.0692 - accuracy: 0.9753 - val_loss: 0.9479 - val_accuracy: 0.7292
# Epoch 14/20
# 81/81 [==============================] - 71s 871ms/step - loss: 0.0726 - accuracy: 0.9718 - val_loss: 0.8779 - val_accuracy: 0.7847
# Epoch 15/20
# 81/81 [==============================] - 72s 883ms/step - loss: 0.0669 - accuracy: 0.9738 - val_loss: 0.7906 - val_accuracy: 0.7604
# Epoch 16/20
# 81/81 [==============================] - 72s 891ms/step - loss: 0.0501 - accuracy: 0.9811 - val_loss: 0.9574 - val_accuracy: 0.7535
# Epoch 17/20
# 81/81 [==============================] - 71s 873ms/step - loss: 0.0415 - accuracy: 0.9846 - val_loss: 1.3059 - val_accuracy: 0.7465
# Epoch 18/20
# 81/81 [==============================] - 71s 874ms/step - loss: 0.0667 - accuracy: 0.9742 - val_loss: 0.6317 - val_accuracy: 0.8333
# Epoch 19/20
# 81/81 [==============================] - 72s 890ms/step - loss: 0.0534 - accuracy: 0.9792 - val_loss: 0.8706 - val_accuracy: 0.8194
# Epoch 20/20
# 81/81 [==============================] - 71s 879ms/step - loss: 0.0562 - accuracy: 0.9780 - val_loss: 0.4631 - val_accuracy: 0.8750

# %%
import json
pheumonia_model_info.history.keys()

# %%
plt.plot(pheumonia_model_info.history['accuracy'])
plt.plot(pheumonia_model_info.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(pheumonia_model_info.history['loss'])
plt.plot(pheumonia_model_info.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
